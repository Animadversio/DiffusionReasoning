# %%
from rule_new_utils import *

# %%
r_dict_M7_withR
# Out:
# {'1-1': {0: [1], 5: [2], 6: [0]},
#  '2-2': {0: [2], 5: [4], 6: [0]},
#  '3-3': {0: [3], 5: [6], 6: [0]},
#  '4-4': {0: [4], 6: [0]},
#  '5-5': {0: [5], 6: [0]},
#  '6-6': {0: [6], 6: [0]},
#  '4-2': {1: [0], 5: [6], 6: [2]},
#  '5-3': {1: [1], 6: [2]},
#  '2-1': {2: [0], 5: [3], 6: [1]},
#  '4-3': {2: [2], 6: [1]},
#  '5-4': {2: [3], 6: [1]},
#  '6-5': {2: [4], 6: [1]},
#  '0-1': {3: [2], 5: [1]},
#  '2-3': {3: [4], 5: [5]},
#  '3-4': {3: [5]},
#  '4-5': {3: [6]},
#  '0-2': {4: [4], 5: [2]},
#  '1-3': {4: [5], 5: [4]},
#  '0-3': {5: [3]},
#  '0-4': {5: [4]},
#  '0-5': {5: [5]},
#  '0-6': {5: [6]},
#  '1-4': {5: [5]},
#  '1-5': {5: [6]},
#  '3-1': {5: [4], 6: [2]},
#  '3-2': {5: [5]},
#  '4-1': {5: [5], 6: [3]},
#  '5-1': {5: [6], 6: [4]},
#  '5-2': {6: [3]},
#  '6-1': {6: [5]},
#  '6-2': {6: [4]},
#  '6-3': {6: [3]},
#  '0-01': {7: [1], 8: [0, 1], 9: [0]},
#  '0-02': {7: [2], 8: [0, 2], 9: [0]},
#  '0-03': {7: [3], 8: [0, 3], 9: [0]},
#  '0-04': {7: [4], 8: [0, 4], 9: [0]},
# ...
